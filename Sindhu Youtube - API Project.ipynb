# %% [markdown]
# **Data extraction and analysis from social media platform Youtube**

# %% [markdown]
# **Problem statement**
#
# Videos are a fast growing medium where people communicate, share knowledge, showcase skills etc. YouTube is one of the biggest platforms which hosts videos. The YouTube platform hosts content from many different professions/arts/ cultures across the world.
#
# People can express their opinion about the video in the form of likes, dislikes, comments which are features provided by the YouTube platform which provides the information on the sentiment about the video.
#
# The assignment involves the steps on programmatic data extraction from YouTube on which analysis can be conducted to understand various attributes related to a video.

# %% [markdown]
# **Steps to be performed**

# %% [markdown]
# 1. Connect to the Youtube API using a Python client

# %% [markdown]
# > 1.a Create a YouTube API key

# %%
# Steps to Obtain a YouTube API Key:
# 1. Navigate to the website: https://console.cloud.google.com/
# 2. Create a new project and begin the setup for the subsequent steps.
# 3. From the left dropdown in the Navigation menu, choose "APIs & Services" >> "Library."
# 4. Search for "YouTube Data API v3" and activate it.
# 5. Proceed to "APIs & Services" > "Credentials" and generate your API Key.


# api_key = "AIzaSyBXoUg_omyWBIVcpgTXaESBhCqzQEQKm0E"

# %% [markdown]
# > 1.b Install the Google API python client

# %%
pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (2.108.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.112.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.23.4)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.14.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sindh\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Downloading google_api_python_client-2.112.0-py2.py3-none-any.whl (13.0 MB)
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.0 MB 991.0 kB/s eta 0:00:14
#    ---------------------------------------- 0.0/13.0 MB 991.0 kB/s eta 0:00:14
#    ---------------------------------------- 0.0/13.0 MB 991.0 kB/s eta 0:00:14
#    ---------------------------------------- 0.0/13.0 MB 991.0 kB/s eta 0:00:14
#    ---------------------------------------- 0.0/13.0 MB 991.0 kB/s eta 0:00:14
#     --------------------------------------- 0.2/13.0 MB 518.9 kB/s eta 0:00:25
#     --------------------------------------- 0.2/13.0 MB 567.2 kB/s eta 0:00:23
#    - -------------------------------------- 0.3/13.0 MB 840.2 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/13.0 MB 1.1 MB/s eta 0:00:12
#    - -------------------------------------- 0.6/13.0 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/13.0 MB 1.5 MB/s eta 0:00:09
#    -- ------------------------------------- 0.9/13.0 MB 1.6 MB/s eta 0:00:08
#    --- ------------------------------------ 1.2/13.0 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.2/13.0 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.2/13.0 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.2/13.0 MB 1.7 MB/s eta 0:00:08
#    --- ------------------------------------ 1.2/13.0 MB 1.7 MB/s eta 0:00:08
#    --- ------------------------------------ 1.2/13.0 MB 1.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/13.0 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.4/13.0 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.4/13.0 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.4/13.0 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.4/13.0 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.5/13.0 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.5/13.0 MB 1.3 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.6/13.0 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/13.0 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/13.0 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/13.0 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/13.0 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/13.0 MB 1.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.7/13.0 MB 1.1 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/13.0 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.9/13.0 MB 1.2 MB/s eta 0:00:10
#    ------ --------------------------------- 2.1/13.0 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 2.2/13.0 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.2/13.0 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.2/13.0 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.2/13.0 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.2/13.0 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.3/13.0 MB 1.2 MB/s eta 0:00:10
#    ------- -------------------------------- 2.3/13.0 MB 1.2 MB/s eta 0:00:10
#    ------- -------------------------------- 2.3/13.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.3/13.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.3/13.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.4/13.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.4/13.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.5/13.0 MB 1.1 MB/s eta 0:00:10
#    ------- -------------------------------- 2.5/13.0 MB 1.1 MB/s eta 0:00:10
#    -------- ------------------------------- 2.6/13.0 MB 1.1 MB/s eta 0:00:10
#    -------- ------------------------------- 2.7/13.0 MB 1.1 MB/s eta 0:00:10
#    -------- ------------------------------- 2.8/13.0 MB 1.2 MB/s eta 0:00:09
#    --------- ------------------------------ 3.0/13.0 MB 1.2 MB/s eta 0:00:09
#    --------- ------------------------------ 3.1/13.0 MB 1.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.3/13.0 MB 1.3 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.5/13.0 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.6/13.0 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.6/13.0 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.6/13.0 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.6/13.0 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.7/13.0 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.7/13.0 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.7/13.0 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.8/13.0 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.8/13.0 MB 1.2 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.9/13.0 MB 1.2 MB/s eta 0:00:08
#    ------------ --------------------------- 3.9/13.0 MB 1.2 MB/s eta 0:00:08
#    ------------ --------------------------- 4.1/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------ --------------------------- 4.2/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.3/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.4/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.4/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.4/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.5/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.5/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.5/13.0 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.5/13.0 MB 1.3 MB/s eta 0:00:07
#    -------------- ------------------------- 4.6/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.6/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.6/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.6/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.6/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.7/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.7/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.7/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.7/13.0 MB 1.2 MB/s eta 0:00:07
#    -------------- ------------------------- 4.7/13.0 MB 1.2 MB/s eta 0:00:08
#    -------------- ------------------------- 4.8/13.0 MB 1.2 MB/s eta 0:00:08
#    --------------- ------------------------ 4.9/13.0 MB 1.2 MB/s eta 0:00:07
#    --------------- ------------------------ 4.9/13.0 MB 1.2 MB/s eta 0:00:07
#    --------------- ------------------------ 4.9/13.0 MB 1.2 MB/s eta 0:00:07
#    --------------- ------------------------ 4.9/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 4.9/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 4.9/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 4.9/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 4.9/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/13.0 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.1/13.0 MB 1.0 MB/s eta 0:00:08
#    --------------- ------------------------ 5.1/13.0 MB 1.0 MB/s eta 0:00:08
#    --------------- ------------------------ 5.1/13.0 MB 998.1 kB/s eta 0:00:08
#    --------------- ------------------------ 5.1/13.0 MB 998.1 kB/s eta 0:00:08
#    --------------- ------------------------ 5.1/13.0 MB 998.1 kB/s eta 0:00:08
#    --------------- ------------------------ 5.1/13.0 MB 975.2 kB/s eta 0:00:09
#    --------------- ------------------------ 5.1/13.0 MB 975.2 kB/s eta 0:00:09
#    --------------- ------------------------ 5.1/13.0 MB 962.9 kB/s eta 0:00:09
#    --------------- ------------------------ 5.2/13.0 MB 955.6 kB/s eta 0:00:09
#    --------------- ------------------------ 5.2/13.0 MB 953.0 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.2/13.0 MB 957.0 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.2/13.0 MB 957.0 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.2/13.0 MB 957.0 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.3/13.0 MB 939.3 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.4/13.0 MB 942.6 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.4/13.0 MB 951.6 kB/s eta 0:00:08
#    ---------------- ----------------------- 5.4/13.0 MB 951.6 kB/s eta 0:00:08
#    ---------------- ----------------------- 5.4/13.0 MB 951.6 kB/s eta 0:00:08
#    ---------------- ----------------------- 5.5/13.0 MB 934.1 kB/s eta 0:00:09
#    ---------------- ----------------------- 5.5/13.0 MB 933.6 kB/s eta 0:00:09
#    ----------------- ---------------------- 5.6/13.0 MB 940.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.6/13.0 MB 940.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.6/13.0 MB 940.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.6/13.0 MB 940.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.6/13.0 MB 940.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.6/13.0 MB 940.0 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.6/13.0 MB 906.3 kB/s eta 0:00:09
#    ----------------- ---------------------- 5.7/13.0 MB 903.9 kB/s eta 0:00:09
#    ----------------- ---------------------- 5.8/13.0 MB 907.8 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.8/13.0 MB 916.3 kB/s eta 0:00:08
#    ------------------ --------------------- 5.9/13.0 MB 923.4 kB/s eta 0:00:08
#    ------------------ --------------------- 6.0/13.0 MB 931.5 kB/s eta 0:00:08
#    ------------------ --------------------- 6.1/13.0 MB 942.1 kB/s eta 0:00:08
#    ------------------- -------------------- 6.2/13.0 MB 948.6 kB/s eta 0:00:08
#    ------------------- -------------------- 6.2/13.0 MB 948.6 kB/s eta 0:00:08
#    ------------------- -------------------- 6.2/13.0 MB 948.6 kB/s eta 0:00:08
#    ------------------- -------------------- 6.3/13.0 MB 935.6 kB/s eta 0:00:08
#    ------------------- -------------------- 6.4/13.0 MB 940.6 kB/s eta 0:00:08
#    ------------------- -------------------- 6.4/13.0 MB 947.6 kB/s eta 0:00:07
#    ------------------- -------------------- 6.4/13.0 MB 947.6 kB/s eta 0:00:07
#    ------------------- -------------------- 6.4/13.0 MB 947.6 kB/s eta 0:00:07
#    ------------------- -------------------- 6.5/13.0 MB 933.6 kB/s eta 0:00:07
#    ------------------- -------------------- 6.5/13.0 MB 933.6 kB/s eta 0:00:07
#    ------------------- -------------------- 6.5/13.0 MB 928.1 kB/s eta 0:00:08
#    -------------------- ------------------- 6.6/13.0 MB 926.6 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 929.9 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.6/13.0 MB 931.3 kB/s eta 0:00:07
#    -------------------- ------------------- 6.7/13.0 MB 894.3 kB/s eta 0:00:08
#    -------------------- ------------------- 6.7/13.0 MB 889.1 kB/s eta 0:00:08
#    -------------------- ------------------- 6.7/13.0 MB 889.1 kB/s eta 0:00:08
#    -------------------- ------------------- 6.7/13.0 MB 889.1 kB/s eta 0:00:08
#    -------------------- ------------------- 6.8/13.0 MB 874.3 kB/s eta 0:00:08
#    -------------------- ------------------- 6.8/13.0 MB 874.3 kB/s eta 0:00:08
#    --------------------- ------------------ 6.8/13.0 MB 874.3 kB/s eta 0:00:08
#    --------------------- ------------------ 6.8/13.0 MB 874.3 kB/s eta 0:00:08
#    --------------------- ------------------ 6.8/13.0 MB 874.3 kB/s eta 0:00:08
#    --------------------- ------------------ 6.9/13.0 MB 864.0 kB/s eta 0:00:08
#    --------------------- ------------------ 6.9/13.0 MB 861.9 kB/s eta 0:00:08
#    --------------------- ------------------ 6.9/13.0 MB 861.6 kB/s eta 0:00:08
#    --------------------- ------------------ 7.0/13.0 MB 864.2 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.2/13.0 MB 878.1 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.2/13.0 MB 886.0 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.3/13.0 MB 885.1 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.3/13.0 MB 885.1 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.3/13.0 MB 876.7 kB/s eta 0:00:07
#    ---------------------- ----------------- 7.4/13.0 MB 877.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.5/13.0 MB 886.5 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.5/13.0 MB 888.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.5/13.0 MB 888.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.5/13.0 MB 888.9 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.6/13.0 MB 876.6 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.6/13.0 MB 881.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.6/13.0 MB 881.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.6/13.0 MB 881.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.6/13.0 MB 881.3 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.7/13.0 MB 871.5 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.7/13.0 MB 868.8 kB/s eta 0:00:07
#    ----------------------- ---------------- 7.8/13.0 MB 870.8 kB/s eta 0:00:06
#    ------------------------ --------------- 7.9/13.0 MB 879.9 kB/s eta 0:00:06
#    ------------------------ --------------- 8.0/13.0 MB 884.9 kB/s eta 0:00:06
#    ------------------------ --------------- 8.0/13.0 MB 884.9 kB/s eta 0:00:06
#    ------------------------ --------------- 8.0/13.0 MB 884.9 kB/s eta 0:00:06
#    ------------------------ --------------- 8.0/13.0 MB 876.8 kB/s eta 0:00:06
#    ------------------------ --------------- 8.1/13.0 MB 875.7 kB/s eta 0:00:06
#    ------------------------- -------------- 8.2/13.0 MB 880.1 kB/s eta 0:00:06
#    ------------------------- -------------- 8.2/13.0 MB 884.1 kB/s eta 0:00:06
#    ------------------------- -------------- 8.4/13.0 MB 895.4 kB/s eta 0:00:06
#    -------------------------- ------------- 8.6/13.0 MB 910.1 kB/s eta 0:00:05
#    -------------------------- ------------- 8.7/13.0 MB 924.5 kB/s eta 0:00:05
#    --------------------------- ------------ 8.9/13.0 MB 937.2 kB/s eta 0:00:05
#    --------------------------- ------------ 9.0/13.0 MB 943.3 kB/s eta 0:00:05
#    ---------------------------- ----------- 9.2/13.0 MB 957.9 kB/s eta 0:00:04
#    ---------------------------- ----------- 9.4/13.0 MB 974.5 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.6/13.0 MB 986.8 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.7/13.0 MB 998.9 kB/s eta 0:00:04
#    ------------------------------ --------- 9.8/13.0 MB 1.0 MB/s eta 0:00:04
#    ------------------------------ --------- 9.8/13.0 MB 1.0 MB/s eta 0:00:04
#    ------------------------------ --------- 9.8/13.0 MB 1.0 MB/s eta 0:00:04
#    ------------------------------ --------- 9.9/13.0 MB 1.0 MB/s eta 0:00:04
#    ------------------------------ --------- 10.0/13.0 MB 1.0 MB/s eta 0:00:04
#    ------------------------------- -------- 10.1/13.0 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 10.3/13.0 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 10.4/13.0 MB 1.0 MB/s eta 0:00:03
#    -------------------------------- ------- 10.6/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.7/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.7/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.7/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.8/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.8/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.8/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.8/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.9/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.9/13.0 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 11.0/13.0 MB 1.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.2/13.0 MB 1.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.3/13.0 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.4/13.0 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.6/13.0 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.7/13.0 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.9/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.9/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.9/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.9/13.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 12.0/13.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 996.6 kB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 996.6 kB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 996.6 kB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 996.6 kB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 996.6 kB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.0 MB 996.6 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 974.3 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 968.5 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 967.1 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 967.1 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 967.1 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 954.4 kB/s eta 0:00:01
#    ------------------------------------- -- 12.2/13.0 MB 950.3 kB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.0 MB 947.5 kB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.0 MB 944.7 kB/s eta 0:00:01
#    -------------------------------------- - 12.4/13.0 MB 962.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.5/13.0 MB 968.5 kB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.0 MB 986.0 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.0 MB 989.1 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.0 MB 989.1 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.0 MB 989.1 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.0 MB 977.1 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.0 MB 975.7 kB/s eta 0:00:01
#    ---------------------------------------  12.9/13.0 MB 969.9 kB/s eta 0:00:01
#    ---------------------------------------  12.9/13.0 MB 967.1 kB/s eta 0:00:01
#    ---------------------------------------  13.0/13.0 MB 964.2 kB/s eta 0:00:01
#    ---------------------------------------  13.0/13.0 MB 964.3 kB/s eta 0:00:01
#    ---------------------------------------- 13.0/13.0 MB 960.0 kB/s eta 0:00:00
# Installing collected packages: google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.108.0
#     Uninstalling google-api-python-client-2.108.0:
#       Successfully uninstalled google-api-python-client-2.108.0
# Successfully installed google-api-python-client-2.112.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# refer to the [supporting](https://developers.google.com/youtube/v3/getting-started) link on how to create YouTube API Key

# %% [markdown]
# Reference link : https://developers.google.com/youtube/v3/quickstart/python

# %% [markdown]
# 2. Search and extract the data

# %% [markdown]
# > 2.a Search videos related to the query string  “avatar movie”
# (For this part, choose/search one video of your choice and perform data collection steps on that specific video )
#
# > Output expected : ID, Snippet with following attributes Channel ID, Video Description, Channel Title, Video Title

# %% [markdown]
# Reference link:  https://developers.google.com/youtube/v3/docs/search/list

# %%
#(2.a)
# Python import statements
import googleapiclient.discovery
from pprint import pprint

# Initializing Path
api_service_name = "youtube"
api_version = "v3"
api_key = "AIzaSyBXoUg_omyWBIVcpgTXaESBhCqzQEQKm0E" 

# Performing Search
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)
response = youtube.search().list(
    q="avatar movie",
    type='video',
    part="id,snippet",
    maxResults=1, # searching one video of my choice
    fields="items(id(videoId),snippet(channelId,description,channelTitle,title))"
).execute()

# Printing the Response
pprint(response)
# Out:
# {'items': [{'id': {'videoId': 'w8PmrLG6v5I'},
#             'snippet': {'channelId': 'UCBOmfqgTZi7yDp4-3Lr_3lA',
#                         'channelTitle': 'Shemaroo Movies',
#                         'description': 'ShemarooMovies #Hindi #Movie '
#                                        '#Bollywood #FullMovie #HD Click here '
#                                        'to Subscribe the channel ...',
#                         'title': 'BOLLYWOOD BLOCKBUSTER HINDI MOVIE - राजेश '
#                                  'खन्ना ,शबाना आजमी और सचिन की सुपरहिट हिंदी '
#                                  'मूवी - AVTAAR'}}]}

# %% [markdown]
# > 2.b  Provide the following statistics for query string “avatar movie” of top 50 videos sorted by relevance in the US region
#
# > Output expected: video ID, title, no of views, no of likes,no of comments exported to CSV file

# %% [markdown]
# Reference link: https://developers.google.com/youtube/v3/docs/videos/list

# %%
#(2.b)
# Python import statements
import csv
import googleapiclient.discovery
from googleapiclient.errors import HttpError
import pandas as pd

#If code executed sucessfully
try:
    youtube_statistics = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)
    response = youtube_statistics.search().list(
        q="avatar movie",
        type='video',
        part="id,snippet",
        order="relevance",
        regionCode="US",
        maxResults=50,
        fields="items(id(videoId),snippet(channelId,description,channelTitle,title))"
    ).execute()
    
    items = response.get("items", [])
    
    video_details= []
    
    for i in items: 
        video_ids = i['id']['videoId']
        video_details_list = youtube_statistics.videos().list(
            part='statistics',
            id= video_ids,
            fields='items(statistics)'
        ).execute()

        video_statistics = video_details_list.get('items', [{}])[0].get('statistics', {})

        video_details.append({
            "VideoID": video_ids,
            "Video_Title": i['snippet']["title"],
            "No_Of_Views": video_statistics.get("viewCount", 0),
            "No_Of_Likes": video_statistics.get("likeCount", 0),
            "No_Of_Comments": video_statistics.get("commentCount", 0)
        })

        
    # Data Exporting to CSV File
    df = pd.DataFrame(video_details)
    csv_file_name = "Aavatar_Movie_Youtube_Data.csv"
    df.to_csv(csv_file_name,  index=False)
    
    # Final Output
    print(f"Data exported to CSV file format: {csv_file_name}")

# If code doesn't exeute sucessfully
except HttpError as e:
    print(f"An error occurred: {e}")
# Out:
# Data exported to CSV file format: Aavatar_Movie_Youtube_Data.csv

# %% [markdown]
#  3. Analyze the exported data obtained in 2.b and carry out the following tasks

# %% [markdown]
# > 3.a Sort the data 2.b  by top 10 comments in descending order and consider the video IDs and Titles of top 10 videos which have highest comments.

# %%
# (3.a)
# Sorting the Data
sorting_data = sorted(video_details, key=lambda x: int(x["No_Of_Comments"]), reverse=True)
Top_10_Comments = sorting_data[:10]

# Converting data into DataFrame
sorted_df = pd.DataFrame(Top_10_Comments)

# Printing Top 10 Comments
print(sorted_df)
# Out:
#        VideoID                                        Video_Title No_Of_Views  \
# 0  d9MyW72ELq0        Avatar: The Way of Water | Official Trailer    58429272
# 1  waJKJW_XU90  Avatar: The Last Airbender | Official Teaser |...    19258153
# 2  a8Gx8wiNbs8  Avatar: The Way of Water | Official Teaser Tra...    27886757
# 3  2r71I8lvTIA  The Last Airbender Film: How it Disrespected a...     5166303
# 4  5PSNL1qE6VY  Avatar | Official Trailer (HD) | 20th Century FOX    12867096
# 5  0sJeBiUCIt4    AVATAR Clip - Final Battle (2009) James Cameron    32541122
# 6  kHNCaWjB-98  Zoe Saldana Performance Capture | AVATAR (2009...    24258498
# 7  X8SVkfbt8cs                           Avatar: The Way of Water           0
# 8  oFErWcXJLdw            TRAINING TO BE IN THE NEXT AVATAR MOVIE     2661850
# 9  PLtgIILX7E8  AVATAR Full Movie 2023: Fallen Kingdom | Super...    49429460
#
#   No_Of_Likes No_Of_Comments
# 0     1042594          43029
# 1      443968          39686
# 2      682270          29021
# 3      155678          27256
# 4       81551           8938
# 5      192634           3703
# 6     1025644           3203
# 7       21525           1756
# 8       50461           1691
# 9      225879           1657

# %% [markdown]
# > 3.b Use a suitable method to retrieve comments of those top 10 videos from 3.a. For doing this, write a program to loop through each video id from 3.a and pass in the part parameter set to "snippet", to retrieve basic details about the comments. Execute this request and print the response using the pprint() method.
#  - Note: pprint() will print out the response from the API in a more human-readable format.
# - Reference link:  [link](https://developers.google.com/youtube/v3/docs )
#
#
# > **Output expected** : Use the python library “ pprint “ to print the output of the program with the following properties  etag, items, id , kind, snippet and snippet to have the text display field which represents the comment of videos.

# %%
# (3.b)
# Collecting data for top 10 video id's from (3.a)
Comments_video_ids = []
for item in Top_10_Comments:
    video_ids = item['VideoID']
    Comments_video_ids.append(video_ids)

# Creating a new list to store comments data
comments_data = []
for video_ids in Comments_video_ids:
    # Retrieving basic details about the comments of a video
    comment_threads = youtube_statistics.commentThreads().list(
        part='snippet',
        videoId=video_ids
    ).execute()

    # Storing comment details in a variable
    comments_data.append(comment_threads)
    
    # Printing Final Output
    pprint(comments_data)
# Out:
# [{'etag': 'moc9p-oKWzvIt6qv7tmM8-qjqFs',
#   'items': [{'etag': 'ltEdk7ilIzsnzndggavzIT5kQ5k',
#              'id': 'Ugza1y8fWhk6yvJtQwR4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'AzQGRynxgFpj1sMtHiulheENX-g',
#                                              'id': 'Ugza1y8fWhk6yvJtQwR4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCD3Y8NgOfBlkPnTijLbDC0A'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCD3Y8NgOfBlkPnTijLbDC0A',
#                                                          'authorDisplayName': '@mdgouse6729',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZS_I8ibdW-zbSdeYnLB7XKFYElMOQkcXku_k48AioFHmP626t0wxsP2g9sNBvtR=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2024-01-08T06:41:33Z',
#                                                          'textDisplay': 'Avatar❌<br>Captain '
#                                                                         'Miller✅',
#                                                          'textOriginal': 'Avatar❌\n'
#                                                                          'Captain '
#                                                                          'Miller✅',
#                                                          'updatedAt': '2024-01-08T06:41:33Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'eWVnHsfmrKDG12h2k-JbZs5lToE',
#              'id': 'UgxrPNJWA4HEozx6iX54AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '2ahtGAgqc2_WRJnT7R9tngH2D1s',
#                                              'id': 'UgxrPNJWA4HEozx6iX54AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCzd6UWCgj7l4Ub9T0xwIkLQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCzd6UWCgj7l4Ub9T0xwIkLQ',
#                                                          'authorDisplayName': '@njabulombongwa4672',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZT9PvSk2McCXSyZRPlG7a8ZyxZjpEf_ahW1SA=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-01-06T23:08:05Z',
#                                                          'textDisplay': 'If a '
#                                                                         'movie '
#                                                                         'can '
#                                                                         'make '
#                                                                         'me '
#                                                                         'cry '
#                                                                         'and '
#                                                                         'smile '
#                                                                         'from '
#                                                                         'the '
#                                                                         'heart '
#                                                                         'at '
#                                                                         'the '
#                                                                         'same '
#                                                                         'time… '
#                                                                         'u '
#                                                                         'know '
#                                                                         'is a '
#                                                                         'definite '
#                                                                         'banger… '
#                                                                         'I '
#                                                                         'don’t '
#                                                                         'no '
#                                                                         'why I '
#                                                                         'hesitated '
#                                                                         'so '
#                                                                         'long '
#                                                                         'to '
#                                                                         'watch '
#                                                                         'this '
#                                                                         'movies '
#                                                                         'I '
#                                                                         'thought '
#                                                                         'it '
#                                                                         'wouldn’t '
#                                                                         'live '
#                                                                         'up to '
#                                                                         'the '
#                                                                         '1st  '
#                                                                         'it '
#                                                                         'it’s '
#                                                                         'clear '
#                                                                         'I was '
#                                                                         'in '
#                                                                         'drugs '
#                                                                         '😂 '
#                                                                         'great '
#                                                                         'movies '
#                                                                         'great '
#                                                                         'cast '
#                                                                         'everything '
#                                                                         'A1',
#                                                          'textOriginal': 'If a '
#                                                                          'movie '
#                                                                          'can '
#                                                                          'make '
#                                                                          'me '
#                                                                          'cry '
#                                                                          'and '
#                                                                          'smile '
#                                                                          'from '
#                                                                          'the '
#                                                                          'heart '
#                                                                          'at '
#                                                                          'the '
#                                                                          'same '
#                                                                          'time… '
#                                                                          'u '
#                                                                          'know '
#                                                                          'is a '
#                                                                          'definite '
#                                                                          'banger… '
#                                                                          'I '
#                                                                          'don’t '
#                                                                          'no '
#                                                                          'why '
#                                                                          'I '
#                                                                          'hesitated '
#                                                                          'so '
#                                                                          'long '
#                                                                          'to '
#                                                                          'watch '
#                                                                          'this '
#                                                                          'movies '
#                                                                          'I '
#                                                                          'thought '
#                                                                          'it '
#                                                                          'wouldn’t '
#                                                                          'live '
#                                                                          'up '
#                                                                          'to '
#                                                                          'the '
#                                                                          '1st  '
#                                                                          'it '
#                                                                          'it’s '
#                                                                          'clear '
#                                                                          'I '
#                                                                          'was '
#                                                                          'in '
#                                                                          'drugs '
#                                                                          '😂 '
#                                                                          'great '
#                                                                          'movies '
#                                                                          'great '
#                                                                          'cast '
#                                                                          'everything '
#                                                                          'A1',
#                                                          'updatedAt': '2024-01-06T23:08:05Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'bB41WN4P1vcsENWh35tS0htkYHY',
#              'id': 'UgxRRb5YcUi1KXtnf1t4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '5mKacoTztKvaXi1I2bTf_vewwic',
#                                              'id': 'UgxRRb5YcUi1KXtnf1t4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCdGUFoZjvjUjAe329i-lmTQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCdGUFoZjvjUjAe329i-lmTQ',
#                                                          'authorDisplayName': '@ioanapopoiu1457',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQLfHxA6hccJLz-QnP1wJaQdcfPn8X9C5lSsZZp=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-01-06T18:23:36Z',
#                                                          'textDisplay': 'I '
#                                                                         'dont '
#                                                                         'understand '
#                                                                         'where '
#                                                                         'is '
#                                                                         'that '
#                                                                         'boy '
#                                                                         'coming '
#                                                                         'from. '
#                                                                         'In '
#                                                                         'Avatar '
#                                                                         '1 is '
#                                                                         'not '
#                                                                         'mentioned '
#                                                                         'any '
#                                                                         'baby, '
#                                                                         'especially '
#                                                                         'a '
#                                                                         'colonel&#39;s  '
#                                                                         'one, '
#                                                                         'being '
#                                                                         'over '
#                                                                         'there '
#                                                                         'with '
#                                                                         'him. '
#                                                                         'And '
#                                                                         'there '
#                                                                         'is no '
#                                                                         'oxygen '
#                                                                         'resource, '
#                                                                         'he '
#                                                                         'keeps '
#                                                                         'that  '
#                                                                         'mask '
#                                                                         'over '
#                                                                         'his '
#                                                                         'face '
#                                                                         'for '
#                                                                         'nothing. '
#                                                                         'How '
#                                                                         'can '
#                                                                         'he '
#                                                                         'live?',
#                                                          'textOriginal': 'I '
#                                                                          'dont '
#                                                                          'understand '
#                                                                          'where '
#                                                                          'is '
#                                                                          'that '
#                                                                          'boy '
#                                                                          'coming '
#                                                                          'from. '
#                                                                          'In '
#                                                                          'Avatar '
#                                                                          '1 is '
#                                                                          'not '
#                                                                          'mentioned '
#                                                                          'any '
#                                                                          'baby, '
#                                                                          'especially '
#                                                                          'a '
#                                                                          "colonel's  "
#                                                                          'one, '
#                                                                          'being '
#                                                                          'over '
#                                                                          'there '
#                                                                          'with '
#                                                                          'him. '
#                                                                          'And '
#                                                                          'there '
#                                                                          'is '
#                                                                          'no '
#                                                                          'oxygen '
#                                                                          'resource, '
#                                                                          'he '
#                                                                          'keeps '
#                                                                          'that  '
#                                                                          'mask '
#                                                                          'over '
#                                                                          'his '
#                                                                          'face '
#                                                                          'for '
#                                                                          'nothing. '
#                                                                          'How '
#                                                                          'can '
#                                                                          'he '
#                                                                          'live?',
#                                                          'updatedAt': '2024-01-06T18:23:36Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'uUDbbjoAwbZos6WW7AICcTWi6eI',
#              'id': 'UgzwhvPoxoWtWChVu9d4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'L0eHibzRiM6eb-Mo-TEDFNQY0AM',
#                                              'id': 'UgzwhvPoxoWtWChVu9d4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCG19-jwrJftNVcVesWZmuvQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCG19-jwrJftNVcVesWZmuvQ',
#                                                          'authorDisplayName': '@gllarocque',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZSKS2jkvVj1dzI1Lhtgal7DAN0m9QcwdeaJ8CES=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-01-06T16:49:44Z',
#                                                          'textDisplay': 'Whoa '
#                                                                         'they '
#                                                                         'got '
#                                                                         'aliens '
#                                                                         'on '
#                                                                         'camera?? '
#                                                                         'We '
#                                                                         'are '
#                                                                         'not '
#                                                                         'alone? '
#                                                                         'Amazing??',
#                                                          'textOriginal': 'Whoa '
#                                                                          'they '
#                                                                          'got '
#                                                                          'aliens '
#                                                                          'on '
#                                                                          'camera?? '
#                                                                          'We '
#                                                                          'are '
#                                                                          'not '
#                                                                          'alone? '
#                                                                          'Amazing??',
#                                                          'updatedAt': '2024-01-06T16:49:44Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'tJ4QDs5bD709vOIFKoHVuJFdbaI',
#              'id': 'UgxemCnDGqreD6lO2Ml4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'bTSEJHLvKA2gPlKPzBbsRYN5XCQ',
#                                              'id': 'UgxemCnDGqreD6lO2Ml4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCSOBaAMxu4uDtJmpwJE_peQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCSOBaAMxu4uDtJmpwJE_peQ',
#                                                          'authorDisplayName': '@niallforde29',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZT0V6bdoP2R0PVxVDKAIqoVZOt5x5q9cIgY3Q=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-01-06T08:48:22Z',
#                                                          'textDisplay': 'This '
#                                                                         'movie '
#                                                                         'was '
#                                                                         'rubbish '
#                                                                         'I '
#                                                                         'could '
#                                                                         'not '
#                                                                         'get '
#                                                                         'into '
#                                                                         'it '
#                                                                         'felt '
#                                                                         'like '
#                                                                         'I was '
#                                                                         'watching '
#                                                                         'a '
#                                                                         'video '
#                                                                         'game '
#                                                                         'not a '
#                                                                         'movie '
#                                                                         'especially '
#                                                                         'the '
#                                                                         'beginning '
#                                                                         'was '
#                                                                         'like '
#                                                                         'it '
#                                                                         'was '
#                                                                         'made '
#                                                                         'on '
#                                                                         'ps5....terrible...ruined '
#                                                                         'avatar '
#                                                                         'for '
#                                                                         'me I '
#                                                                         'won&#39;t '
#                                                                         'be '
#                                                                         'watching '
#                                                                         'avatar '
#                                                                         '3',
#                                                          'textOriginal': 'This '
#                                                                          'movie '
#                                                                          'was '
#                                                                          'rubbish '
#                                                                          'I '
#                                                                          'could '
#                                                                          'not '
#                                                                          'get '
#                                                                          'into '
#                                                                          'it '
#                                                                          'felt '
#                                                                          'like '
#                                                                          'I '
#                                                                          'was '
#                                                                          'watching '
#                                                                          'a '
#                                                                          'video '
#                                                                          'game '
#                                                                          'not '
#                                                                          'a '
#                                                                          'movie '
#                                                                          'especially '
#                                                                          'the '
#                                                                          'beginning '
#                                                                          'was '
#                                                                          'like '
#                                                                          'it '
#                                                                          'was '
#                                                                          'made '
#                                                                          'on '
#                                                                          'ps5....terrible...ruined '
#                                                                          'avatar '
#                                                                          'for '
#                                                                          'me I '
#                                                                          "won't "
#                                                                          'be '
#                                                                          'watching '
#                                                                          'avatar '
#                                                                          '3',
#                                                          'updatedAt': '2024-01-06T08:48:22Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 1,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'eWztcHqfxxlrKKXpXTIvs3kmTew',
#              'id': 'Ugx3EUfoCtmp7fdEMUh4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': '4HjegbSM4o1GoTfDrLdZ-Xzvd7k',
#                                              'id': 'Ugx3EUfoCtmp7fdEMUh4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UC_CbtsNRD2_QcExtmw_dGGQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UC_CbtsNRD2_QcExtmw_dGGQ',
#                                                          'authorDisplayName': '@nerd26373',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/2UtvrjnWVotoMaC-SAYX9U527Sl2-lN_Vuk5dYE4Eyo58EIwqB4Q2WLCmrE9PTwvffSMSp6ZLkY=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-01-06T05:02:22Z',
#                                                          'textDisplay': 'Pandora '
#                                                                         'certainly '
#                                                                         'is '
#                                                                         'the '
#                                                                         'best '
#                                                                         'place '
#                                                                         'to '
#                                                                         'be. '
#                                                                         'For '
#                                                                         'the '
#                                                                         'blue-skinned '
#                                                                         'lizards, '
#                                                                         'this '
#                                                                         'is '
#                                                                         'their '
#                                                                         'primary '
#                                                                         'and '
#                                                                         'serene '
#                                                                         'sanctuary '
#                                                                         'filled '
#                                                                         'with '
#                                                                         'all '
#                                                                         'kinds '
#                                                                         'of '
#                                                                         'different '
#                                                                         'fauna '
#                                                                         'and '
#                                                                         'flora '
#                                                                         'species. '
#                                                                         'What '
#                                                                         'I '
#                                                                         'find '
#                                                                         'incredible '
#                                                                         'is '
#                                                                         'the '
#                                                                         'fact '
#                                                                         'that '
#                                                                         'this '
#                                                                         'is '
#                                                                         'all a '
#                                                                         'product '
#                                                                         'of '
#                                                                         'James '
#                                                                         'Cameron&#39;s '
#                                                                         'vision. '
#                                                                         'There&#39;s '
#                                                                         'always '
#                                                                         'possibilities '
#                                                                         'that '
#                                                                         'stretch '
#                                                                         'beyond '
#                                                                         'Earth '
#                                                                         'and '
#                                                                         'the '
#                                                                         'other '
#                                                                         'discoveries '
#                                                                         'that '
#                                                                         'we '
#                                                                         'may '
#                                                                         'find '
#                                                                         'out '
#                                                                         'there '
#                                                                         'in '
#                                                                         'the '
#                                                                         'intergalactic '
#                                                                         'space.',
#                                                          'textOriginal': 'Pandora '
#                                                                          'certainly '
#                                                                          'is '
#                                                                          'the '
#                                                                          'best '
#                                                                          'place '
#                                                                          'to '
#                                                                          'be. '
#                                                                          'For '
#                                                                          'the '
#                                                                          'blue-skinned '
#                                                                          'lizards, '
#                                                                          'this '
#                                                                          'is '
#                                                                          'their '
#                                                                          'primary '
#                                                                          'and '
#                                                                          'serene '
#                                                                          'sanctuary '
#                                                                          'filled '
#                                                                          'with '
#                                                                          'all '
#                                                                          'kinds '
#                                                                          'of '
#                                                                          'different '
#                                                                          'fauna '
#                                                                          'and '
#                                                                          'flora '
#                                                                          'species. '
#                                                                          'What '
#                                                                          'I '
#                                                                          'find '
#                                                                          'incredible '
#                                                                          'is '
#                                                                          'the '
#                                                                          'fact '
#                                                                          'that '
#                                                                          'this '
#                                                                          'is '
#                                                                          'all '
#                                                                          'a '
#                                                                          'product '
#                                                                          'of '
#                                                                          'James '
#                                                                          "Cameron's "
#                                                                          'vision. '
#                                                                          "There's "
#                                                                          'always '
#                                                                          'possibilities '
#                                                                          'that '
#                                                                          'stretch '
#                                                                          'beyond '
#                                                                          'Earth '
#                                                                          'and '
#                                                                          'the '
#                                                                          'other '
#                                                                          'discoveries '
#                                                                          'that '
#                                                                          'we '
#                                                                          'may '
#                                                                          'find '
#                                                                          'out '
#                                                                          'there '
#                                                                          'in '
#                                                                          'the '
#                                                                          'intergalactic '
#                                                                          'space.',
#                                                          'updatedAt': '2024-01-06T05:02:22Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'd9MyW72ELq0'}},
#             {'etag': 'yN8GT0OrrW-ZkMn2v-yn67Huvd0',
#              'id': 'UgwyvPq9i4vTps2B_u94AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'gcpO3T2uXlVdSlMMjTO2BmAGmuU',
#                                              'id': 'UgwyvPq9i4vTps2B_u94AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCclzW-0QXfiAa2Npfw2dR0g'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCclzW-0QXfiAa2Npfw2dR0g',
#                                                          'authorDisplayName': '@Archive1911.',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/3oH0cMud1ziGCdTdiUX1cIUuHq1nk2_vxAxpBtZsOhJ_4zwXLgWMCBBASbJoG9DbQBj20xu7=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCgjxQJ6TlKqhHax8742ZMdA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2024-01-04T13:47:40Z',
#                                                          'textDisplay': 'Neteyam '
#                                                                         'great '
#                                                                         'warrior '
#                                                                         '🙌',
#                                                          'textOriginal': 'Neteyam '
#                                                                          'great '
#                                                                          'warrior '
#                                                                          '🙌',
#                                                          'updatedAt': '2024-01-04T13:47:40Z',
#                                                          'videoId': 'd9MyW72ELq0',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
# ...
#                                                                          'aggressive '
#                                                                          '💀 '
#                                                                          'this '
#                                                                          'is '
#                                                                          'me '
#                                                                          'sometimes '
#                                                                          'just '
#                                                                          'yelling '
#                                                                          'my '
#                                                                          'ass '
#                                                                          'off '
#                                                                          'to '
#                                                                          'my '
#                                                                          'parents '
#                                                                          'cuz '
#                                                                          'they '
#                                                                          'annoy '
#                                                                          'me '
#                                                                          'sometimes '
#                                                                          '😭',
#                                                          'updatedAt': '2023-12-09T02:12:34Z',
#                                                          'videoId': 'kHNCaWjB-98',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'kHNCaWjB-98'}},
#             {'etag': '7mwAAOsq17y2sBjiHXz4g6MHN-s',
#              'id': 'UgyEXoo7UwLnor5lecJ4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'CKC_5y_2cBHENVeprNpgqoIgQPU',
#                                              'id': 'UgyEXoo7UwLnor5lecJ4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCc_2W9dOE26rUOst3pP2LYQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCc_2W9dOE26rUOst3pP2LYQ',
#                                                          'authorDisplayName': '@rage7447',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZS-rC6v4XykF9HT_Egfq-0jijbPVNUpjUI3ATaiLy5OT4pqiDGFLzcpNQWAVB29=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2023-12-06T12:04:45Z',
#                                                          'textDisplay': '“I '
#                                                                         'trusted '
#                                                                         'you!” '
#                                                                         'That '
#                                                                         'part '
#                                                                         'already '
#                                                                         'makes '
#                                                                         'me '
#                                                                         'tear.',
#                                                          'textOriginal': '“I '
#                                                                          'trusted '
#                                                                          'you!” '
#                                                                          'That '
#                                                                          'part '
#                                                                          'already '
#                                                                          'makes '
#                                                                          'me '
#                                                                          'tear.',
#                                                          'updatedAt': '2023-12-06T12:04:45Z',
#                                                          'videoId': 'kHNCaWjB-98',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'kHNCaWjB-98'}},
#             {'etag': 'MREdup9QaxACB8gBroXnsFVgZew',
#              'id': 'UgzK3d7aCC0zvIs0eL54AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'QYg-XvT-mfEwhYyuGPB86LQU3Ko',
#                                              'id': 'UgzK3d7aCC0zvIs0eL54AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCqzeMYa3Ed4q0uSrqm-nFDw'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCqzeMYa3Ed4q0uSrqm-nFDw',
#                                                          'authorDisplayName': '@katielink6906',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZTSwrmsrcRSK5YHOiPKA0aUAFWCYFPG-rXdHFcz=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2023-12-04T07:07:49Z',
#                                                          'textDisplay': 'She '
#                                                                         'can '
#                                                                         'act '
#                                                                         'her '
#                                                                         'ass '
#                                                                         'off '
#                                                                         'that '
#                                                                         'baby '
#                                                                         'need '
#                                                                         'a '
#                                                                         'Grammy '
#                                                                         'for '
#                                                                         'something!',
#                                                          'textOriginal': 'She '
#                                                                          'can '
#                                                                          'act '
#                                                                          'her '
#                                                                          'ass '
#                                                                          'off '
#                                                                          'that '
#                                                                          'baby '
#                                                                          'need '
#                                                                          'a '
#                                                                          'Grammy '
#                                                                          'for '
#                                                                          'something!',
#                                                          'updatedAt': '2023-12-04T07:07:49Z',
#                                                          'videoId': 'kHNCaWjB-98',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'kHNCaWjB-98'}},
#             {'etag': '5wVPZWl1lNTcyjOjf0ERL_LYy0o',
#              'id': 'UgzUzgeonl3JdRHSQO14AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'KXylB8NS2YKDkzYfeGBX_p0idZQ',
#                                              'id': 'UgzUzgeonl3JdRHSQO14AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UC7Awm1TNdfMGtXJk90wkFvA'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UC7Awm1TNdfMGtXJk90wkFvA',
#                                                          'authorDisplayName': '@Cloudy0nP4wz',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/0QwHdOwazhMaNbqfjmOHcVfptrnuq6JUwNkagDbNettmqe3iqgvQk_vRSkO44GpIB3ymQP5_8Q=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                                                          'likeCount': 0,
#                                                          'publishedAt': '2023-12-04T06:24:35Z',
#                                                          'textDisplay': 'The '
#                                                                         'ears '
#                                                                         'at '
#                                                                         'the '
#                                                                         'behind '
#                                                                         'the '
#                                                                         'scenes '
#                                                                         'tho, '
#                                                                         'it’s '
#                                                                         'giving<br><br><br><br><br><br><b>✨SHREK✨</b>',
#                                                          'textOriginal': 'The '
#                                                                          'ears '
#                                                                          'at '
#                                                                          'the '
#                                                                          'behind '
#                                                                          'the '
#                                                                          'scenes '
#                                                                          'tho, '
#                                                                          'it’s '
#                                                                          'giving\n'
#                                                                          '\n'
#                                                                          '\n'
#                                                                          '\n'
#                                                                          '\n'
#                                                                          '\n'
#                                                                          '*✨SHREK✨*',
#                                                          'updatedAt': '2023-12-04T06:24:35Z',
#                                                          'videoId': 'kHNCaWjB-98',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'kHNCaWjB-98'}},
#             {'etag': '-pJ9XxjZmiQobwaqax7J4vsu5cA',
#              'id': 'UgxvDW2UhVn7tIALRk14AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'rxJv6kxbLwZldQa5197NyHt7umY',
#                                              'id': 'UgxvDW2UhVn7tIALRk14AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCilM094JN5PWnq2KxqHTVHw'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCilM094JN5PWnq2KxqHTVHw',
#                                                          'authorDisplayName': '@danielcelier',
#                                                          'authorProfileImageUrl': 'https://yt3.ggpht.com/o5kloHlk0IFGh7GmCaCIRO-SSxMgNk3FIsOY8ag9BHihkhZB1BsCdbLdlo-oxvljIybmZdg3rA=s48-c-k-c0x00ffffff-no-rj',
#                                                          'canRate': True,
#                                                          'channelId': 'UCmQynT5NWU3Vsa9t0OGUhcA',
#                                                          'likeCount': 1,
#                                                          'publishedAt': '2023-12-03T17:17:26Z',
#                                                          'textDisplay': 'She '
#                                                                         'is so '
#                                                                         'good!',
#                                                          'textOriginal': 'She '
#                                                                          'is '
#                                                                          'so '
#                                                                          'good!',
#                                                          'updatedAt': '2023-12-03T17:17:26Z',
#                                                          'videoId': 'kHNCaWjB-98',
#                                                          'viewerRating': 'none'}},
#                          'totalReplyCount': 0,
#                          'videoId': 'kHNCaWjB-98'}}],
#   'kind': 'youtube#commentThreadListResponse',
#   'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpSklCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBWUFDSU9DZ3dJcGZDeXF3WVFrUFBlbVFN',
#   'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}]
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# > 3.c Write a program to export the output of question 3.b in JSON file format and submit the file as part of the assignment

# %%
# (3.c)

import json

# Storing the (3.b) data into a json file
json_file_name = "Avatar_Movie_Data.json"
with open(json_file_name, 'w') as json_file:
    json.dump(comments_data, json_file, indent=4)

# Printing Final Output
print(f"Data exported to JSON file format: '{json_file_name}'")
# Out:
# Data exported to JSON file format: 'Avatar_Movie_Data.json'

# %% [markdown]
# >3.d Write a function to get  the likes vs views ratio of the top 10 videos obtained in 3.a with the highest comments

# %%
#  (3.d)
# Creating a function using (2.b) video details
def likes_vs_views(video_details):
    ratio_data = []
    
    # Creating loop to include details(Views & Likes) of every Video ID
    for i in video_details:
        Views = int(i["No_Of_Views"])
        Likes = int(i["No_Of_Likes"])
        
        if Views > 0:
            ratio = Likes / Views
        else:
            ratio = 0.0
        
        ratio_data.append({
            'Video ID': i['VideoID'],
            'Likes-vs-Views': ratio
        })
    
    return ratio_data

# Calculating ratios for top 10 comments from(3.a)
data = likes_vs_views(Top_10_Comments)

# Printing the Final Output
pprint(data)
# Out:
# [{'Likes-vs-Views': 0.017843693140657306, 'Video ID': 'd9MyW72ELq0'},
#  {'Likes-vs-Views': 0.023053508817797844, 'Video ID': 'waJKJW_XU90'},
#  {'Likes-vs-Views': 0.024465734757182413, 'Video ID': 'a8Gx8wiNbs8'},
#  {'Likes-vs-Views': 0.030133346805249324, 'Video ID': '2r71I8lvTIA'},
#  {'Likes-vs-Views': 0.006337949137862965, 'Video ID': '5PSNL1qE6VY'},
#  {'Likes-vs-Views': 0.005919709836679879, 'Video ID': '0sJeBiUCIt4'},
#  {'Likes-vs-Views': 0.04227978170783698, 'Video ID': 'kHNCaWjB-98'},
#  {'Likes-vs-Views': 0.0, 'Video ID': 'X8SVkfbt8cs'},
#  {'Likes-vs-Views': 0.018957116291301163, 'Video ID': 'oFErWcXJLdw'},
#  {'Likes-vs-Views': 0.004569724209004104, 'Video ID': 'PLtgIILX7E8'}]
